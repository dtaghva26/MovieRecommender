# %%
# !git init

# %%
# !git add .
# !git commit -m "installe"
# !git branch -M main
# !git remote add origin https://github.com/dtaghva26/MovieRecommender.git
# !git push -u origin main

# %%
# !git stash
# !git pull
# !git stash pop
