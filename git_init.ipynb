# %%
# !git init

# %%
# !git add .
# !git commit -m "adjusted env vars and setting up postgresql"
# !git branch -M main
# !git remote add origin https://github.com/dtaghva26/MovieRecommender.git
# !git push -u origin main
# Out:
# warning: in the working copy of 'git_init.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main 59c6382] adjusted env vars and setting up postgresql
#  3 files changed, 60 insertions(+), 124 deletions(-)
# branch 'main' set up to track 'origin/main'.
# To https://github.com/dtaghva26/MovieRecommender.git
#    4931b94..59c6382  main -> main

# %%
# !git stash
# !git pull
# !git stash pop
